# %% [markdown]
# # Tarefa 02
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os monitores
# - Divirta-se :)

# %% [markdown]
# #### 1. Carregue os dados da tarefa anterior

# %%
# importando libs
import pandas as pd
import yfinance as yf
import plotly.express as px

# %%
# importando os dados
dados = pd.read_csv('ativos.csv',header=[0,1], index_col=0) # header mantem os indices superiores e index_col o indice das datas
dados.head()
# Out:
# Price              Close                               High             \
# Ticker           BTC-USD       NVDA     ^BVSP       BTC-USD       NVDA
# Date
# 2022-01-03  46458.117188  30.070990  103922.0  47510.726562  30.660010
# 2022-01-04  45897.574219  29.241367  103514.0  47406.546875  30.417411
# 2022-01-05  43569.003906  27.558170  101006.0  46929.046875  29.367162
# 2022-01-06  43160.929688  28.131214  101561.0  43748.718750  28.390783
# 2022-01-07  41557.902344  27.201761  102719.0  43153.570312  28.374812
#
# Price                          Low                               Open  \
# Ticker         ^BVSP       BTC-USD       NVDA     ^BVSP       BTC-USD
# Date
# 2022-01-03  106125.0  45835.964844  29.735547  103413.0  47343.542969
# 2022-01-04  104276.0  45752.464844  28.301930  103096.0  46458.851562
# 2022-01-05  103514.0  42798.222656  27.487289  100850.0  45899.359375
# 2022-01-06  102235.0  42645.539062  27.020063  101000.0  43565.511719
# 2022-01-07  102719.0  41077.445312  27.012076  101104.0  43153.570312
#
# Price                                 Volume
# Ticker           NVDA     ^BVSP      BTC-USD         NVDA       ^BVSP
# Date
# 2022-01-03  29.765498  104823.0  33071628362  391547000.0  11128500.0
# 2022-01-04  30.226728  103922.0  42494677905  527154000.0  11491600.0
# 2022-01-05  28.900937  103514.0  36851084859  498064000.0         0.0
# 2022-01-06  27.594107  101006.0  30208048289  454186000.0  11749200.0
# 2022-01-07  28.094278  101561.0  84196607520  409939000.0  11733200.0

# %% [markdown]
# #### 2. Média móvel
#
# 1. Faça uma média móvel  em 90 dias dos valores de fechamento ajustados dos ativos que você escolheu
# 2. Utilizando a fução ```rolling()```, calcule o desvio pardão desses ativos ao longo do tempo, utilizando a mesma janela móvel do item acima
# 2. Monte um gráfico de linhas para as médias móveis dos ativos da sua base
# 4. Monte um gráfico de linhas para os desvios padrão em janela móvel
# 5. Compare os dois gráficos que você fez com o da tarefa anterior. Veja se eles apontam conclusões semelhantes quanto aos períodos de maior volatilidade (variação) dos ativos.

# %%
datas = pd.date_range('2022-01-03', periods=14, freq='D')

# %% [markdown]
# #### 3. Gráfico de *candlestick*
# 1. Selecione o período dos últimos 60 dias (corridos) para um dos ativos da sua base
# 2. Monte um gráfico de *candlestick* para esses dados.
