# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui

url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado'

# %%
r = requests.get(url)
r.json()
# Out:
# {'items': [{'id_pleito': 7085,
#    'tipo_interessado': 'Estado',
#    'interessado': 'Rio de Janeiro',
#    'cod_ibge': 33,
#    'uf': 'RJ',
#    'num_pvl': None,
#    'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#    'num_processo': '17944.000493/2012-72',
#    'data_protocolo': '2012-04-16T03:00:00Z',
#    'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#    'finalidade': 'Infraestrutura',
#    'tipo_credor': 'Instituição Financeira Internacional',
#    'credor': 'Corporação Andina de Fomento',
#    'moeda': 'Dólar dos EUA',
#    'valor': 120666000,
#    'pvl_assoc_divida': 1,
#    'pvl_contradado_credor': 0,
#    'data_status': '04/10/2012'},
#   {'id_pleito': 5516,
#    'tipo_interessado': 'Estado',
#    'interessado': 'Rio de Janeiro',
#    'cod_ibge': 33,
#    'uf': 'RJ',
#    'num_pvl': None,
#    'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#    'num_processo': '17944.000131/2011-09',
# ...

# %%
data = r.json()
data
# Out:
# {'items': [{'id_pleito': 7085,
#    'tipo_interessado': 'Estado',
#    'interessado': 'Rio de Janeiro',
#    'cod_ibge': 33,
#    'uf': 'RJ',
#    'num_pvl': None,
#    'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#    'num_processo': '17944.000493/2012-72',
#    'data_protocolo': '2012-04-16T03:00:00Z',
#    'tipo_operacao': 'Operação contratual externa (com garantia da União)',
#    'finalidade': 'Infraestrutura',
#    'tipo_credor': 'Instituição Financeira Internacional',
#    'credor': 'Corporação Andina de Fomento',
#    'moeda': 'Dólar dos EUA',
#    'valor': 120666000,
#    'pvl_assoc_divida': 1,
#    'pvl_contradado_credor': 0,
#    'data_status': '04/10/2012'},
#   {'id_pleito': 5516,
#    'tipo_interessado': 'Estado',
#    'interessado': 'Rio de Janeiro',
#    'cod_ibge': 33,
#    'uf': 'RJ',
#    'num_pvl': None,
#    'status': 'Encaminhado à PGFN com manifestação técnica favorável',
#    'num_processo': '17944.000131/2011-09',
# ...

# %%
df = pd.DataFrame(data['items'])
df.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 0       7085           Estado  Rio de Janeiro        33  RJ    None
# 1       5516           Estado  Rio de Janeiro        33  RJ    None
# 2       8556           Estado  Rio de Janeiro        33  RJ    None
# 3       7080           Estado  Rio de Janeiro        33  RJ    None
# 4       9750           Estado  Rio de Janeiro        33  RJ    None
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.000493/2012-72
# 1  Encaminhado à PGFN com manifestação técnica fa...  17944.000131/2011-09
# 2  Encaminhado à PGFN com manifestação técnica fa...  17944.000797/2010-78
# 3  Encaminhado à PGFN com manifestação técnica fa...  17944.000492/2012-28
# 4                                           Deferido  17944.001046/2006-92
#
#          data_protocolo                                      tipo_operacao  \
# ...

# %%
# 2) Status de verificação mais frequentes e sua quantidade

df.status.value_counts()
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    34
# Deferido                                                 14
# Arquivado a pedido                                        3
# Arquivado por decurso de prazo                            1
# Name: status, dtype: int64

# %%
# 3) Extraindo anos

df['data_status'] = df['data_status'].astype(str)

# %%
df['ano_status'] = df['data_status'].str.slice(-4)

# %%
df.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 0       7085           Estado  Rio de Janeiro        33  RJ    None
# 1       5516           Estado  Rio de Janeiro        33  RJ    None
# 2       8556           Estado  Rio de Janeiro        33  RJ    None
# 3       7080           Estado  Rio de Janeiro        33  RJ    None
# 4       9750           Estado  Rio de Janeiro        33  RJ    None
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.000493/2012-72
# 1  Encaminhado à PGFN com manifestação técnica fa...  17944.000131/2011-09
# 2  Encaminhado à PGFN com manifestação técnica fa...  17944.000797/2010-78
# 3  Encaminhado à PGFN com manifestação técnica fa...  17944.000492/2012-28
# 4                                           Deferido  17944.001046/2006-92
#
#          data_protocolo                                      tipo_operacao  \
# ...

# %%
# Frequencia dos anos

df.ano_status.value_counts()
# Out:
# 2012    11
# 2009     9
# 2013     7
# 2011     6
# 2002     4
# 2016     4
# 2014     4
# 2010     3
# 2006     2
# 2008     2
# Name: ano_status, dtype: int64

# %%
df.uf.value_counts()
# Out:
# RJ    52
# Name: uf, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Criando função para consulta

def consulta(uf = str, tipo = str):
    url = f'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={uf}&tipo_interessado={tipo}'
    r = requests.get(url)    
    dados = r.json()
    df = pd.DataFrame(dados['items'])
    return df

# %%
df = consulta(uf = 'MG', tipo = 'Estado')
df.head()
# Out:
#    id_pleito tipo_interessado   interessado  cod_ibge  uf num_pvl  \
# 0      13618           Estado  Minas Gerais        31  MG    None
# 1       4926           Estado  Minas Gerais        31  MG    None
# 2       9197           Estado  Minas Gerais        31  MG    None
# 3      13695           Estado  Minas Gerais        31  MG    None
# 4      13672           Estado  Minas Gerais        31  MG    None
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  19405.000037/2006-15
# 1                                          Arquivado  10951.000367/1998-24
# 2  Encaminhado à PGFN com manifestação técnica fa...  17944.000924/2009-03
# 3                                          Arquivado  19405.000053/2003-57
# 4  Encaminhado à PGFN com manifestação técnica fa...  19405.000048/2005-14
#
#          data_protocolo                                      tipo_operacao  \
# ...

# %%
# 2) Solicitações com statu 'Arquivado por decurso de prazo'
df.status.value_counts()
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    20
# Deferido                                                  7
# Arquivado a pedido                                        5
# Arquivado                                                 3
# Arquivado pela STN                                        3
# Indeferido                                                1
# Arquivado por decurso de prazo                            1
# Name: status, dtype: int64

# %% [markdown]
# #### Apenas um status arquivado por decurso de prazo

# %%
# 3) Município com mais ações deferidas
df_ba = consulta('BA', 'Município')
df_ba.head()
# Out:
#    id_pleito tipo_interessado           interessado  cod_ibge  uf num_pvl  \
# 0       6923        Município          Capim Grosso   2906873  BA    None
# 1      12058        Município               Itiruçu   2916906  BA    None
# 2      10834        Município  Formosa do Rio Preto   2911105  BA    None
# 3      10837        Município        Barra do Choça   2902906  BA    None
# 4      10747        Município      Lauro de Freitas   2919207  BA    None
#
#                            status          num_processo        data_protocolo  \
# 0  Arquivado por decurso de prazo  17944.000459/2014-60  2015-08-27T03:00:00Z
# 1  Arquivado por decurso de prazo  17944.001594/2010-07  2010-11-22T02:00:00Z
# 2                        Deferido  17944.001297/2010-53  2010-09-06T03:00:00Z
# 3                        Deferido  17944.001298/2008-83  2008-05-13T03:00:00Z
# 4                        Deferido  17944.001273/2011-85  2012-01-20T02:00:00Z
#
#                  tipo_operacao  \
# ...

# %%
df_ba.interessado.value_counts()
# Out:
# Camaçari                  19
# Salvador                  18
# Luís Eduardo Magalhães    18
# Vitória da Conquista      15
# Irecê                     14
#                           ..
# Jandaíra                   1
# Banzaê                     1
# Feira da Mata              1
# Encruzilhada               1
# Santa Cruz Cabrália        1
# Name: interessado, Length: 293, dtype: int64

# %% [markdown]
# #### O município com mais solicitações deferidas foi "Camaçari "

# %%
# 4) Salvando arquivo

df_ba_estado = consulta('BA', 'Estado')
df_ba_estado.head()
# Out:
#    id_pleito tipo_interessado interessado  cod_ibge  uf               num_pvl  \
# 0      10859           Estado       Bahia        29  BA                  None
# 1      22572           Estado       Bahia        29  BA  00000.000000/2032-81
# 2      23723           Estado       Bahia        29  BA  PVL02.000640/2016-75
# 3      18495           Estado       Bahia        29  BA                  None
# 4      18372           Estado       Bahia        29  BA                  None
#
#                                               status          num_processo  \
# 0                                           Deferido  17944.001302/2013-71
# 1                                 Arquivado pela STN  17944.000644/2016-16
# 2  Encaminhado à PGFN com manifestação técnica fa...  17944.001273/2016-90
# 3                                           Deferido  19407.000035/2002-74
# 4                                           Deferido  19407.000009/2005-99
#
# ...

# %%
df_ba_estado.to_csv('df_bahia_estado', sep = ';', decimal = ',')
