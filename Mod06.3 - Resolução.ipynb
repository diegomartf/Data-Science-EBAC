# %% [markdown]
# # Módulo 6 tarefa 3
#
# #### 1) A base 'sinasc_RO_2019.csv' contém dados do sistema de nascidos vivos do DataSUS, cujo dicionário de dados está no arquivo 'Estrutura_SINASC_para_CD.pdf'. Carregue esse arquivo.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### 2) Categorize a variável APGAR5 conforme as seguintes quebras:
#
# - 0 a 3: 'asfixia grave'
# - 4 a 5: 'asfixia moderada'
# - 6 a 7: 'asfixia leve'
# - 8 a 10: 'normal'

# %%
# Criando data frame

df = pd.read_csv('sinasc_RO_2019.csv')
df.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...

# %%
# criando a coluna CAT_AP5 para armazenas as categorias de APGAR5

df[['CAT_AP5']] = 'normal'

# %%
# categorizando os tipos de APGAR5

df.loc[df['APGAR5'] <= 3, 'CAT_AP5'] = 'asfixia grave'
df.loc[df['APGAR5'] >= 4, 'CAT_AP5'] = 'asfixia moderada'
df.loc[df['APGAR5'] >= 6, 'CAT_AP5'] = 'asfixia leve'
df.loc[df['APGAR5'] >= 8, 'CAT_AP5'] = 'normal'

# %%
df.loc[df['APGAR5'] == 9]
# Out:
#        ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 1           1  2679477.0      110001        1        29        2.0
# 8           1  2679477.0      110001        1        20        5.0
# 10          1  2679477.0      110001        1        31        5.0
# 12          1  2679477.0      110001        1        21        5.0
# 13          1  2679477.0      110001        1        18        5.0
# ...       ...        ...         ...      ...       ...        ...
# 27021       1  2604388.0      510340        1        25        5.0
# 27022       1  2604388.0      510340        1        34        2.0
# 27023       1  2604388.0      510340        1        32        2.0
# 27024       1  2752654.0      510675        1        19        1.0
# 27026       1  9659366.0      510787        1        21        2.0
#
#                 ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  CONTADOR  \
# 1          8 a 11 anos    999992.0         1.0         0.0  ...         2
# ...

# %% [markdown]
# #### 3) Monte um gráfico comparando a distribuição de APGAR5 por sexo para cada grupo de tempo de gestação (GESTACAO).

# %%
sns.boxplot(data=df
           , x='APGAR5'
           , y='GESTACAO'
           , hue='SEXO')
# Out:
# <Axes: xlabel='APGAR5', ylabel='GESTACAO'>

# %% [markdown]
# ####  4) Monte uma tabela cruzada com APGAR5 nas colunas e GESTACAO nas linhas

# %%
# Criando tabela cruzada

freq = pd.crosstab(df['CAT_AP5'], df['GESTACAO'])
freq
# Out:
# GESTACAO          22 a 27 semanas  28 a 31 semanas  32 a 36 semanas  \
# CAT_AP5
# asfixia grave                  21                3                8
# asfixia leve                   12               18               73
# asfixia moderada                1               12               19
# normal                         52              132             2149
#
# GESTACAO          37 a 41 semanas  42 semanas e mais  Menos de 22 semanas
# CAT_AP5
# asfixia grave                  33                  1                    2
# asfixia leve                  196                  6                    1
# asfixia moderada               28                  1                    0
# normal                      22332                692                    4

# %% [markdown]
# ####  5) Da tabela cruzada do intem anterior, calcule os percentuais de linha. Ou seja, a distribuição da variável APGAR5 para cada classe de GESTACAO dado.

# %%
# calculando percentual das linhas

pct = freq.div(freq.sum(axis = 1), axis = 0)
pct
# Out:
# GESTACAO          22 a 27 semanas  28 a 31 semanas  32 a 36 semanas  \
# CAT_AP5
# asfixia grave            0.308824         0.044118         0.117647
# asfixia leve             0.039216         0.058824         0.238562
# asfixia moderada         0.016393         0.196721         0.311475
# normal                   0.002050         0.005205         0.084736
#
# GESTACAO          37 a 41 semanas  42 semanas e mais  Menos de 22 semanas
# CAT_AP5
# asfixia grave            0.485294           0.014706             0.029412
# asfixia leve             0.640523           0.019608             0.003268
# asfixia moderada         0.459016           0.016393             0.000000
# normal                   0.880565           0.027286             0.000158

# %% [markdown]
# ####  6) Os médicos costumam classificar parto prematuro quando a gestação tem menos que 37 semanas. Faça um gráfico de barras da tabela cruzada acima e conclua se você acha que este conjunto de dados corrobora ou não com a afirmação dos médicos.

# %%
pct.plot.bar()
# Out:
# <Axes: xlabel='CAT_AP5'>

# %% [markdown]
# Observando o gráfico acima, nota-se que o número de ocorrencias de asfixia grave, leve e moderada estão concentradas em maior número nas gestações com menos de 37 semanas corroborando assim com a afirmação dos médicos.

# %% [markdown]
# #### 7) Veja se há relação entre APGAR5 e o peso do bebê. Isso pode ser feito de diversas formas. Fique à vontade para escolher a melhor maneira na sua opinião, ou até testar mais de um dos gráficos que vimos. Fique à vontade também para consultar a documentação e utilizar algum outro recurso se achar conveniente.

# %%
sns.boxplot(x = 'CAT_AP5'
           , y = 'PESO'
           , data = df)
# Out:
# <Axes: xlabel='CAT_AP5', ylabel='PESO'>
